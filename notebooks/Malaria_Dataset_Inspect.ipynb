# %% [markdown]
# # Malaria Dataset Inspect
#
# This notebook loads each CSV used in the malaria project, displays the first and last rows,
# and explains what each dataset is for.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
elif not (PROJECT_ROOT / "data").exists() and (PROJECT_ROOT.parent / "data").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

pd.set_option("display.max_columns", 100)

# %% [markdown]
# ## Processed District Malaria Data

# %%
processed_district = pd.read_csv(PROJECT_ROOT / "data/processed/district_malaria_2000_2024_from_pdf.csv")
print("Shape:", processed_district.shape)
display(processed_district.head())
display(processed_district.tail())
# Out:
# Shape: (16781, 5)
#    year                        state   district  total_cases  total_deaths
# 0  2000  Andaman And Nicobar Islands    Andaman          530             0
# 1  2000  Andaman And Nicobar Islands   Nicobars          472             1
# 2  2000               Andhra Pradesh   Adilabad         1798             2
# 3  2000               Andhra Pradesh  Anantapur         1301             0
# 4  2000               Andhra Pradesh   Chittoor          291             1
#        year        state                 district  total_cases  total_deaths
# 16776  2024  West Bengal        Paschim Bardhaman            0             0
# 16777  2024  West Bengal          Purba Bardhaman           20             0
# 16778  2024  West Bengal                  Purulia           49             0
# 16779  2024  West Bengal  Pvt. Hospital & Others#           67             0
# 16780  2024  West Bengal            Rampurhat HD#           14             0

# %% [markdown]
# This CSV is the district-level malaria dataset extracted from the long district-wise PDF.
# It contains annual malaria cases and deaths by district and state from 2000 to 2024.
# This is close to the original extracted table and is useful for checking source values.

# %% [markdown]
# ## Processed State Malaria Situation Data

# %%
processed_state_situation = pd.read_csv(PROJECT_ROOT / "data/processed/state_malaria_situation_2021_2025_from_pdf.csv")
print("Shape:", processed_state_situation.shape)
display(processed_state_situation.head())
display(processed_state_situation.tail())
# Out:
# Shape: (185, 7)
#    year                        state  tested  positive  pf  deaths  \
# 0  2021  Andaman And Nicobar Islands   35471        27  11       0
# 1  2022  Andaman And Nicobar Islands   31737        50  20       0
# 2  2023  Andaman And Nicobar Islands   38986        42  11       0
# 3  2024  Andaman And Nicobar Islands   47413        96  46       0
# 4  2025  Andaman And Nicobar Islands   55701        48  25       0
#
#   source_status
# 0      reported
# 1      reported
# 2      reported
# 3      reported
# 4   provisional
#      year  state     tested  positive      pf  deaths source_status
# 180  2021  India  114391977    161753  101566      90      reported
# 181  2022  India  152049892    176522  101070      83      reported
# 182  2023  India  164738643    227564  137945      83      reported
# 183  2024  India  181653330    255500  153472      86      reported
# 184  2025  India  186637835    233555  135430      55   provisional

# %% [markdown]
# This CSV is the state/UT-level malaria situation table extracted from the PDF.
# It contains tested, positive, Pf, and deaths for 2021 to 2025.
# It is useful for recent state-level trends and surveillance indicators.

# %% [markdown]
# ## Processed State Epidemiological Data

# %%
processed_state_epi = pd.read_csv(PROJECT_ROOT / "data/processed/state_epidemiological_2024_2025_from_pdf.csv")
print("Shape:", processed_state_epi.shape)
display(processed_state_epi.head())
display(processed_state_epi.tail())
# Out:
# Shape: (74, 12)
#    year                        state    tested  positive    pf  pf_percent  \
# 0  2024  Andaman And Nicobar Islands     47413        96    46       47.92
# 1  2025  Andaman And Nicobar Islands     55701        48    25       52.08
# 2  2024               Andhra Pradesh  12364281      7866  6201       78.83
# 3  2025               Andhra Pradesh  12892737      7831  6312       80.60
# 4  2024            Arunachal Pradesh    158497        19     2       10.53
#
#      tpr   tfr  deaths  imported_cases  indigenous_cases     category
# 0  0.202  0.10     NaN             NaN               NaN          NaN
# 1  0.086  0.05     0.0             4.0              44.0  Category II
# 2  0.064  0.05     NaN             NaN               NaN          NaN
# 3  0.061  0.05     8.0           287.0            7544.0  Category II
# 4  0.012  0.00     NaN             NaN               NaN          NaN
#     year        state     tested  positive      pf  pf_percent    tpr   tfr  \
# 69  2025  Uttarakhand     530679       196      56       28.57  0.037  0.01
# 70  2024  West Bengal   13653675     21802    3841       17.62  0.160  0.03
# 71  2025  West Bengal   13658022     21080    3925       18.62  0.154  0.03
# 72  2024        India  181653330    255500  153472       60.07  0.141  0.08
# 73  2025        India  186637835    233555  135430       57.99  0.125  0.07
#
#     deaths  imported_cases  indigenous_cases     category
# 69     0.0           122.0              74.0   Category I
# 70     NaN             NaN               NaN          NaN
# 71     0.0             0.0           21080.0  Category II
# 72     NaN             NaN               NaN          NaN
# 73    55.0          4541.0          229014.0          NaN

# %% [markdown]
# This CSV is the state/UT-level epidemiological report for 2024 and 2025.
# It includes indicators such as Pf percentage, TPR, TFR, deaths, imported cases,
# indigenous cases, and category where available.

# %% [markdown]
# ## Analysis-Ready District Malaria Data

# %%
clean_district = pd.read_csv(PROJECT_ROOT / "data/analysis_ready/district_malaria_clean.csv")
print("Shape:", clean_district.shape)
display(clean_district.head())
display(clean_district.tail())
# Out:
# Shape: (16781, 8)
#    year                        state   district  total_cases  total_deaths  \
# 0  2000  Andaman And Nicobar Islands    Andaman          530             0
# 1  2000  Andaman And Nicobar Islands   Nicobars          472             1
# 2  2000               Andhra Pradesh   Adilabad         1798             2
# 3  2000               Andhra Pradesh  Anantapur         1301             0
# 4  2000               Andhra Pradesh   Chittoor          291             1
#
#    population_2011  cases_per_100k  deaths_per_100k
# 0           380581      139.260762         0.000000
# 1           380581      124.020905         0.262756
# 2         49577103        3.626674         0.004034
# 3         49577103        2.624195         0.000000
# 4         49577103        0.586965         0.002017
#        year        state                 district  total_cases  total_deaths  \
# 16776  2024  West Bengal        Paschim Bardhaman            0             0
# 16777  2024  West Bengal          Purba Bardhaman           20             0
# 16778  2024  West Bengal                  Purulia           49             0
# 16779  2024  West Bengal  Pvt. Hospital & Others#           67             0
# 16780  2024  West Bengal            Rampurhat HD#           14             0
#
#        population_2011  cases_per_100k  deaths_per_100k
# 16776         91276115        0.000000              0.0
# 16777         91276115        0.021912              0.0
# 16778         91276115        0.053683              0.0
# 16779         91276115        0.073404              0.0
# 16780         91276115        0.015338              0.0

# %% [markdown]
# This is the cleaned district-level dataset used for analysis.
# It keeps district cases and deaths, and adds state population plus per-capita rates.
# Use this when district-level analysis needs normalized case or death rates.

# %% [markdown]
# ## Analysis-Ready State-Year Malaria Data

# %%
clean_state_year = pd.read_csv(PROJECT_ROOT / "data/analysis_ready/state_year_malaria_clean.csv")
print("Shape:", clean_state_year.shape)
display(clean_state_year.head())
display(clean_state_year.tail())
# Out:
# Shape: (858, 9)
#    year                        state  total_cases  total_deaths  \
# 0  2000  Andaman And Nicobar Islands         1990             5
# 1  2000               Andhra Pradesh        80557             6
# 2  2000            Arunachal Pradesh        46165             0
# 3  2000                        Assam        84915            43
# 4  2000                        Bihar         9509             2
#
#    district_count  population_2011  cases_per_100k  deaths_per_100k  \
# 0               4           380581      522.884747         1.313781
# 1              23         49577103      162.488316         0.012102
# 2              12          1383727     3336.279483         0.000000
# 3              23         31205576      272.114830         0.137796
# 4              37        104099452        9.134534         0.001921
#
#   selected_region
# 0              no
# 1              no
# 2              no
# 3              no
# 4              no
#      year                                         state  total_cases  \
# 853  2024  The Dadra And Nagar Haveli And Daman And Diu           23
# 854  2024                                       Tripura         1662
# 855  2024                                 Uttar Pradesh          248
# 856  2024                                   Uttarakhand           61
# 857  2024                                   West Bengal         1280
#
#      total_deaths  district_count  population_2011  cases_per_100k  \
# 853             0               6           586956        3.918522
# 854             0               8          3673917       45.237821
# 855             0              74        199812341        0.124116
# 856             0              15         10086292        0.604781
# 857             1              28         91276115        1.402338
#
#      deaths_per_100k selected_region
# 853         0.000000              no
# 854         0.000000             yes
# 855         0.000000              no
# 856         0.000000              no
# 857         0.001096              no

# %% [markdown]
# This is the main state-year dataset for modelling.
# It aggregates district values to state-year level and includes population,
# cases per 100,000, deaths per 100,000, district count, and selected-region labels.
# This is used by the geospatial, SIR, and ARIMA notebook.

# %% [markdown]
# ## Selected Regions State-Year Data

# %%
selected_regions = pd.read_csv(PROJECT_ROOT / "data/analysis_ready/selected_regions_state_year.csv")
print("Shape:", selected_regions.shape)
display(selected_regions.head())
display(selected_regions.tail())
# Out:
# Shape: (75, 9)
#    year    state  total_cases  total_deaths  district_count  population_2011  \
# 0  2000  Mizoram         9059            33               4          1097206
# 1  2000   Odisha       509497           467              30         41974218
# 2  2000  Tripura        12245             6               4          3673917
# 3  2001  Mizoram        10929            43               5          1097206
# 4  2001   Odisha       454541           305              30         41974218
#
#    cases_per_100k  deaths_per_100k selected_region
# 0      825.642587         3.007639             yes
# 1     1213.833215         1.112588             yes
# 2      333.295499         0.163313             yes
# 3      996.075486         3.919045             yes
# 4     1082.905225         0.726637             yes
#     year    state  total_cases  total_deaths  district_count  population_2011  \
# 70  2023   Odisha        40300             1              28         41974218
# 71  2023  Tripura        22412             1               8          3673917
# 72  2024  Mizoram         4308             0               9          1097206
# 73  2024   Odisha         8742             0              28         41974218
# 74  2024  Tripura         1662             0               8          3673917
#
#     cases_per_100k  deaths_per_100k selected_region
# 70       96.011318         0.002382             yes
# 71      610.030112         0.027219             yes
# 72      392.633653         0.000000             yes
# 73       20.827071         0.000000             yes
# 74       45.237821         0.000000             yes

# %% [markdown]
# This CSV contains only the three selected project regions:
# Odisha, Mizoram, and Tripura.
# It is a smaller state-year file for focused comparison, geospatial interpretation,
# SIR modelling, and ARIMA forecasting.

# %% [markdown]
# ## AI/ML State-Year Feature Data

# %%
aiml_features = pd.read_csv(PROJECT_ROOT / "data/analysis_ready/aiml_state_year_features.csv")
print("Shape:", aiml_features.shape)
display(aiml_features.head())
display(aiml_features.tail())
# Out:
# Shape: (706, 21)
#                          state  year  population_2011  district_count  \
# 0  Andaman And Nicobar Islands  2003           380581               1
# 1  Andaman And Nicobar Islands  2004           380581               4
# 2  Andaman And Nicobar Islands  2005           380581               1
# 3  Andaman And Nicobar Islands  2006           380581               7
# 4  Andaman And Nicobar Islands  2008           380581               8
#
#    total_cases  cases_per_100k  total_cases_lag1  total_cases_lag2  \
# 0          427      112.196878              1557               434
# 1         1800      472.961078               427              1557
# 2         3234      849.753403              1800               427
# 3        18866     4957.157609              3234              1800
# 4        29938     7866.393751             18866              3234
#
#    total_cases_lag3  total_deaths_lag1  cases_per_100k_lag1  \
# 0              1990                  4           409.111332
# 1               434                  0           112.196878
# 2              1557                  4           472.961078
# 3               427                  0           849.753403
# 4              1800                 22          4957.157609
#
#    cases_per_100k_lag2  cases_per_100k_lag3  deaths_per_100k_lag1  \
# 0           114.036171           522.884747              1.051025
# 1           409.111332           114.036171              0.000000
# 2           112.196878           409.111332              1.051025
# 3           472.961078           112.196878              0.000000
# 4           849.753403           472.961078              5.780635
#
#    cases_rate_roll3  cases_yoy_change  rate_yoy_change  next_year_cases  \
# 0        348.677417         -0.725755        -0.725755             1800
# 1        211.781460          3.215457         3.215457             3234
# 2        331.423096          0.796667         0.796667            18866
# 3        478.303786          4.833643         4.833643            29938
# 4       2093.290697          0.586876         0.586876            22081
#
#    next_year_rate  high_risk_next_year selected_region
# 0      472.961078                    1              no
# 1      849.753403                    1              no
# 2     4957.157609                    1              no
# 3     7866.393751                    1              no
# 4     5801.918645                    1              no
#                                             state  year  population_2011  \
# 701                                     Telangana  2021         35003674
# 702                                     Telangana  2022         35003674
# 703                                     Telangana  2023         35003674
# 704                                        Ladakh  2023           274289
# 705  The Dadra And Nagar Haveli And Daman And Diu  2023           586956
#
#      district_count  total_cases  cases_per_100k  total_cases_lag1  \
# 701              28          829        2.368323               820
# 702              30          566        1.616973               829
# 703              30          411        1.174162               566
# 704               2           10        3.645790                 7
# 705               6          137       23.340761               156
#
#      total_cases_lag2  total_cases_lag3  total_deaths_lag1  \
# 701              1702              1776                  0
# 702               820              1702                  0
# 703               829               820                  0
# 704                34                 0                  0
# 705              8301                90                  0
#
#      cases_per_100k_lag1  cases_per_100k_lag2  cases_per_100k_lag3  \
# 701             2.342611             4.862347             5.073753
# 702             2.368323             2.342611             4.862347
# 703             1.616973             2.368323             2.342611
# 704             2.552053            12.395685             0.000000
# 705            26.577801          1414.245702            15.333347
#
#      deaths_per_100k_lag1  cases_rate_roll3  cases_yoy_change  \
# 701                   0.0          4.092904          0.010976
# 702                   0.0          3.191094         -0.317250
# 703                   0.0          2.109302         -0.273852
# 704                   0.0          4.982579          0.428571
# 705                   0.0        485.385617         -0.121795
#
#      rate_yoy_change  next_year_cases  next_year_rate  high_risk_next_year  \
# 701         0.010976              566        1.616973                    0
# 702        -0.317250              411        1.174162                    0
# 703        -0.273852               47        0.134272                    0
# 704         0.428571                1        0.364579                    0
# 705        -0.121795               23        3.918522                    0
#
#     selected_region
# 701              no
# 702              no
# 703              no
# 704              no
# 705              no

# %% [markdown]
# This is the machine-learning-ready dataset.
# It contains lag features, rolling averages, year-over-year changes, next-year cases,
# next-year case rate, and the high-risk classification target.
# This is used by the standalone AI/ML risk model notebook.

# %% [markdown]
# ## State Population Data

# %%
population = pd.read_csv(PROJECT_ROOT / "data/raw/state_population_2011.csv")
print("Shape:", population.shape)
display(population.head())
display(population.tail())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 population = pd.read_csv(PROJECT_ROOT / "data/raw/state_population_2011.csv")
#       2 print("Shape:", population.shape)
#       3 display(population.head())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Downloads\\malaria-risk-project\\data\\raw\\state_population_2011.csv'

# %% [markdown]
# This CSV contains state/UT population denominators from Census 2011.
# It is used to calculate per-capita malaria rates such as cases per 100,000 population.
